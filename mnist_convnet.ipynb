# %% [markdown]
# # MNIST example -- ConvNet
# ####  A practical example for training convolutional neural networks
#
# - DataLoader: a data class you define according to your dataset
# - Deep convolutional neural net
# - Save checkpointd during training

# %%
import numpy as np
import tensorflow as tf

# %%
# DataLoader class: need to customize according to your dataset
class DataLoader(object):
    def __init__(self):
        # for the MNIST example, we preload the whole dataset
        from tensorflow.contrib.learn.python.learn.datasets.mnist import read_data_sets
        data_dir = 'MNIST_data/'
        self.dataset = read_data_sets(data_dir, one_hot=False)
        
        self.num = self.dataset.train.images.shape[0]
        self.h = 28
        self.w = 28
        self.c = 1
        
        self._idx = 0
        
    def next_batch(self, batch_size):
        images_batch = np.zeros((batch_size, self.h, self.w, self.c)) 
        labels_batch = np.zeros(batch_size)
        for i in range(batch_size):
            # when your dataset is huge, you might need to load images on the fly
            # you might also want data augmentation
            images_batch[i, ...] = self.dataset.train.images[self._idx].reshape((self.h, self.w, self.c))
            labels_batch[i, ...] = self.dataset.train.labels[self._idx]
            
            self._idx += 1
            if self._idx == self.num:
                self._idx = 0
        
        return images_batch, labels_batch
    
    def load_test(self):
        return self.dataset.test.images.reshape((-1, self.h, self.w, self.c)), self.dataset.test.labels

# %%
def init_weights(shape):
    return tf.Variable(tf.random_normal(shape, stddev=0.01))

def init_bias(shape):
    return tf.Variable(tf.zeros(shape))

def cnn(x, keep_dropout):
    weights = {
        'wc1': init_weights([5, 5, 1, 32]),  # 5x5x1 conv, 32 outputs
        'wc2': init_weights([5, 5, 32, 64]),          # 5x5x32 conv, 64 outputs
        'wf3': init_weights([7*7*64, 1024]),         # FC 7*7*64 inputs, 1024 outputs
        'wo': init_weights([1024, 10]),         # FC 1024 inputs, 10 outputs 
    }
    biases = {
        'bc1': init_bias(32),
        'bc2': init_bias(64),
        'bf3': init_bias(1024),
        'bo': init_bias(10),
    }

    # Conv + ReLU + Pool
    conv1 = tf.nn.conv2d(x, weights['wc1'], strides=[1, 1, 1, 1], padding='SAME')
    conv1 = tf.nn.relu(tf.nn.bias_add(conv1, biases['bc1']))
    pool1 = tf.nn.max_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

    # Conv + ReLU + Pool
    conv2 = tf.nn.conv2d(pool1, weights['wc2'], strides=[1, 1, 1, 1], padding='SAME')
    conv2 = tf.nn.relu(tf.nn.bias_add(conv2, biases['bc2']))
    pool2 = tf.nn.max_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

    # FC + ReLU + Dropout
    fc3 = tf.reshape(pool2, [-1, weights['wf3'].get_shape().as_list()[0]])
    fc3 = tf.add(tf.matmul(fc3, weights['wf3']), biases['bf3'])
    fc3 = tf.nn.relu(fc3)
    fc3 = tf.nn.dropout(fc3, keep_dropout)

    # Output FC
    out = tf.add(tf.matmul(fc3, weights['wo']), biases['bo'])
    
    return out

# %%
# Parameters
learning_rate = 0.001
training_iters = 1000
batch_size = 100
step_display = 10
step_save = 500
path_save = 'convnet'

# Network Parameters
h = 28 # MNIST data input (img shape: 28*28)
w = 28
c = 1
dropout = 0.5 # Dropout, probability to keep units

# %%
# Construct dataloader
loader = DataLoader()

# tf Graph input
x = tf.placeholder(tf.float32, [None, h, w, c])
y = tf.placeholder(tf.int64, None)
keep_dropout = tf.placeholder(tf.float32)

# Construct model
logits = cnn(x, keep_dropout)

# Define loss and optimizer
loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits))
train_optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)

# Evaluate model
correct_pred = tf.equal(tf.argmax(logits, 1), y)
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# define initialization
init = tf.global_variables_initializer()

# define saver
saver = tf.train.Saver()

# define summary writer
#writer = tf.train.SummaryWriter('.', graph=tf.get_default_graph())
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Launch the graph
with tf.Session() as sess:
    # Initialization
    sess.run(init)

    step = 1
    while step < training_iters:
        # Load a batch of data
        images_batch, labels_batch = loader.next_batch(batch_size)
        
        # Run optimization op (backprop)
        sess.run(train_optimizer, feed_dict={x: images_batch, y: labels_batch, keep_dropout: dropout})
        
        if step % step_display == 0:
            # Calculate batch loss and accuracy while training
            l, acc = sess.run([loss, accuracy], feed_dict={x: images_batch, y: labels_batch, keep_dropout: 1.}) 
            print "Iter " + str(step) + ", Minibatch Loss= " + \
            "{:.6f}".format(l) + ", Training Accuracy= " + \
            "{:.4f}".format(acc)
        
        step += 1
        
        # Save model
        if step % step_save == 0:
            saver.save(sess, path_save, global_step=step)
            print "Model saved at Iter %d !" %(step)
        
    print "Optimization Finished!"

    # Calculate accuracy for 500 mnist test images
    images_test, labels_test = loader.load_test()
    print "Testing Accuracy:", \
    sess.run(accuracy, feed_dict={x: images_test[:500],
                                      y: labels_test[:500],
                                      keep_dropout: 1.})
# Out:
# Iter 10, Minibatch Loss= 1.936813, Training Accuracy= 0.5400
# Iter 20, Minibatch Loss= 0.761027, Training Accuracy= 0.6900
# Iter 30, Minibatch Loss= 0.820092, Training Accuracy= 0.6800
# Iter 40, Minibatch Loss= 0.511465, Training Accuracy= 0.8500
# Iter 50, Minibatch Loss= 0.301381, Training Accuracy= 0.9200
# Iter 60, Minibatch Loss= 0.368739, Training Accuracy= 0.9400
# Iter 70, Minibatch Loss= 0.271282, Training Accuracy= 0.9200
# Iter 80, Minibatch Loss= 0.407122, Training Accuracy= 0.8600
# Iter 90, Minibatch Loss= 0.399242, Training Accuracy= 0.9000
# Iter 100, Minibatch Loss= 0.203792, Training Accuracy= 0.9100
# Iter 110, Minibatch Loss= 0.315384, Training Accuracy= 0.9300
# Iter 120, Minibatch Loss= 0.168785, Training Accuracy= 0.9300
# Iter 130, Minibatch Loss= 0.192625, Training Accuracy= 0.9100
# Iter 140, Minibatch Loss= 0.066964, Training Accuracy= 0.9700
# Iter 150, Minibatch Loss= 0.071145, Training Accuracy= 0.9800
# Iter 160, Minibatch Loss= 0.195383, Training Accuracy= 0.9400
# Iter 170, Minibatch Loss= 0.136091, Training Accuracy= 0.9300
# Iter 180, Minibatch Loss= 0.036037, Training Accuracy= 1.0000
# Iter 190, Minibatch Loss= 0.185667, Training Accuracy= 0.9700
# Iter 200, Minibatch Loss= 0.110319, Training Accuracy= 0.9400
# Iter 210, Minibatch Loss= 0.110965, Training Accuracy= 0.9600
# Iter 220, Minibatch Loss= 0.040175, Training Accuracy= 0.9900
# Iter 230, Minibatch Loss= 0.093640, Training Accuracy= 0.9800
# Iter 240, Minibatch Loss= 0.083832, Training Accuracy= 0.9600
# Iter 250, Minibatch Loss= 0.151797, Training Accuracy= 0.9500
# Iter 260, Minibatch Loss= 0.079429, Training Accuracy= 0.9700
# Iter 270, Minibatch Loss= 0.123236, Training Accuracy= 0.9800
# Iter 280, Minibatch Loss= 0.048130, Training Accuracy= 0.9900
# Iter 290, Minibatch Loss= 0.037976, Training Accuracy= 1.0000
# Iter 300, Minibatch Loss= 0.099963, Training Accuracy= 0.9700
# Iter 310, Minibatch Loss= 0.119427, Training Accuracy= 0.9500
# Iter 320, Minibatch Loss= 0.034972, Training Accuracy= 0.9900
# Iter 330, Minibatch Loss= 0.056787, Training Accuracy= 1.0000
# Iter 340, Minibatch Loss= 0.114269, Training Accuracy= 0.9700
# Iter 350, Minibatch Loss= 0.046183, Training Accuracy= 0.9900
# Iter 360, Minibatch Loss= 0.093677, Training Accuracy= 0.9800
# Iter 370, Minibatch Loss= 0.104347, Training Accuracy= 0.9600
# Iter 380, Minibatch Loss= 0.120945, Training Accuracy= 0.9800
# Iter 390, Minibatch Loss= 0.091686, Training Accuracy= 0.9700
# Iter 400, Minibatch Loss= 0.057926, Training Accuracy= 0.9800
# Iter 410, Minibatch Loss= 0.069634, Training Accuracy= 0.9800
# Iter 420, Minibatch Loss= 0.040858, Training Accuracy= 0.9900
# Iter 430, Minibatch Loss= 0.127216, Training Accuracy= 0.9600
# Iter 440, Minibatch Loss= 0.161822, Training Accuracy= 0.9500
# Iter 450, Minibatch Loss= 0.095859, Training Accuracy= 0.9500
# Iter 460, Minibatch Loss= 0.031527, Training Accuracy= 0.9900
# Iter 470, Minibatch Loss= 0.137891, Training Accuracy= 0.9500
# Iter 480, Minibatch Loss= 0.203428, Training Accuracy= 0.9500
# Iter 490, Minibatch Loss= 0.061741, Training Accuracy= 0.9800
# Model saved at Iter 500 !
# Iter 500, Minibatch Loss= 0.048879, Training Accuracy= 0.9900
# Iter 510, Minibatch Loss= 0.048763, Training Accuracy= 0.9700
# Iter 520, Minibatch Loss= 0.022642, Training Accuracy= 0.9900
# Iter 530, Minibatch Loss= 0.024506, Training Accuracy= 0.9900
# Iter 540, Minibatch Loss= 0.001319, Training Accuracy= 1.0000
# Iter 550, Minibatch Loss= 0.256085, Training Accuracy= 0.9800
# Iter 560, Minibatch Loss= 0.031648, Training Accuracy= 0.9900
# Iter 570, Minibatch Loss= 0.047366, Training Accuracy= 0.9900
# Iter 580, Minibatch Loss= 0.046779, Training Accuracy= 0.9900
# Iter 590, Minibatch Loss= 0.059537, Training Accuracy= 0.9800
# Iter 600, Minibatch Loss= 0.018435, Training Accuracy= 0.9900
# Iter 610, Minibatch Loss= 0.086733, Training Accuracy= 0.9600
# Iter 620, Minibatch Loss= 0.034021, Training Accuracy= 0.9800
# Iter 630, Minibatch Loss= 0.098139, Training Accuracy= 0.9500
# Iter 640, Minibatch Loss= 0.103788, Training Accuracy= 0.9700
# Iter 650, Minibatch Loss= 0.013991, Training Accuracy= 1.0000
# Iter 660, Minibatch Loss= 0.095768, Training Accuracy= 0.9900
# Iter 670, Minibatch Loss= 0.038887, Training Accuracy= 0.9900
# Iter 680, Minibatch Loss= 0.073636, Training Accuracy= 0.9700
# Iter 690, Minibatch Loss= 0.007038, Training Accuracy= 1.0000
# Iter 700, Minibatch Loss= 0.018749, Training Accuracy= 1.0000
# Iter 710, Minibatch Loss= 0.061616, Training Accuracy= 0.9700
# Iter 720, Minibatch Loss= 0.056261, Training Accuracy= 0.9800
# Iter 730, Minibatch Loss= 0.011340, Training Accuracy= 1.0000
# Iter 740, Minibatch Loss= 0.081754, Training Accuracy= 0.9800
# Iter 750, Minibatch Loss= 0.026711, Training Accuracy= 0.9900
# Iter 760, Minibatch Loss= 0.037128, Training Accuracy= 0.9800
# Iter 770, Minibatch Loss= 0.035824, Training Accuracy= 0.9900
# Iter 780, Minibatch Loss= 0.021334, Training Accuracy= 1.0000
# Iter 790, Minibatch Loss= 0.019735, Training Accuracy= 1.0000
# Iter 800, Minibatch Loss= 0.035931, Training Accuracy= 0.9900
# Iter 810, Minibatch Loss= 0.060209, Training Accuracy= 0.9800
# Iter 820, Minibatch Loss= 0.035245, Training Accuracy= 0.9900
# Iter 830, Minibatch Loss= 0.013821, Training Accuracy= 0.9900
# Iter 840, Minibatch Loss= 0.009703, Training Accuracy= 1.0000
# Iter 850, Minibatch Loss= 0.038653, Training Accuracy= 0.9800
# Iter 860, Minibatch Loss= 0.051770, Training Accuracy= 0.9700
# Iter 870, Minibatch Loss= 0.013859, Training Accuracy= 1.0000
# Iter 880, Minibatch Loss= 0.027497, Training Accuracy= 1.0000
# Iter 890, Minibatch Loss= 0.021280, Training Accuracy= 1.0000
# Iter 900, Minibatch Loss= 0.018250, Training Accuracy= 0.9900
# Iter 910, Minibatch Loss= 0.050164, Training Accuracy= 0.9800
# Iter 920, Minibatch Loss= 0.045046, Training Accuracy= 0.9800
# Iter 930, Minibatch Loss= 0.040256, Training Accuracy= 0.9900
# Iter 940, Minibatch Loss= 0.032031, Training Accuracy= 0.9900
# Iter 950, Minibatch Loss= 0.012883, Training Accuracy= 1.0000
# Iter 960, Minibatch Loss= 0.038675, Training Accuracy= 0.9800
# Iter 970, Minibatch Loss= 0.016751, Training Accuracy= 1.0000
# Iter 980, Minibatch Loss= 0.043694, Training Accuracy= 0.9900
# Iter 990, Minibatch Loss= 0.145798, Training Accuracy= 0.9500
# Model saved at Iter 1000 !
# Optimization Finished!
# Testing Accuracy: 0.996
